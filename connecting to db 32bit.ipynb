# %%
import pyodbc
import pandas as pd
import os
import itertools
import re

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Must run in 32 bit Python

# %%
ps_cnxn = pyodbc.connect("Provider=MSDASQL.1;Persist Security Info=True;Extended Properties=&quot;DSN=mypstar;&quot;;Initial Catalog=focus2000")
ps_cursor = ps_cnxn.cursor()

# %%
plant_query = '''SELECT ss_hist_base_0.start_time, ss_hist_base_0.mach_name, ss_hist_base_0.gross_pieces, ss_hist_base_0.user_text_1, ss_hist_base_0.user_text_4, ss_hist_base_0.mat_formula, ss_hist_base_0.tool, ss_hist_base_0.std_shot_weight, ss_hist_base_0.act_shot_weight
FROM focus2000.dg_def dg_def_0, focus2000.dg_set dg_set_0, focus2000.ss_hist_base ss_hist_base_0
WHERE dg_def_0.mach_seq = ss_hist_base_0.mach_seq AND dg_set_0.dg_seq = dg_def_0.dg_seq AND ((dg_set_0.dg_name Like 'Team%') AND (ss_hist_base_0.start_time>{ts '2019-01-01 06:00:00'}))'''

# %%
# %%time
# Pull Raw Data
ps_cursor.execute(plant_query)
rows = ps_cursor.fetchall()
df = pd.DataFrame.from_records(rows,columns = ['start_time','mach_name','gross_pieces','user_text_1','shop_order','resin','tool','std_shot_weight','act_shot_weight'])
df.head()
# Out:
# Wall time: 13.5 s
#            start_time mach_name  gross_pieces user_text_1 shop_order  resin  \
# 0 2019-01-02 18:00:00   14-N400          3498       R7500     185652  RM129
# 1 2019-01-03 06:00:01   14-N400          4226       R7500     185652  RM129
# 2 2019-01-03 18:00:01   14-N400           128       R7500     185652  RM129
# 3 2019-01-03 19:34:32   14-N400          3424       R7500     185786  RM129
# 4 2019-01-04 06:00:00   14-N400          4286       R7500     185786  RM129
#
#      tool  std_shot_weight  act_shot_weight
# 0  R7500D           1.7975              0.0
# 1  R7500D           1.7975              0.0
# 2  R7500D           1.7975              0.0
# 3  R7500D           1.7975              0.0
# 4  R7500D           1.7975              0.0

# %%
len(df['shop_order'].unique())
# Out:
# 4127

# %%
print('-*'*5+' Summary Stats '+'-*'*5)
print('Earliest entry = {}'.format(df.start_time.min()))
print('Most Recent entry = {}'.format(df.start_time.max()))
print('Number of entries = {}'.format(df.shape[0]))
print('Number of Shop Orders = {}'.format(len(df.shop_order.unique())))
# Out:
# -*-*-*-*-* Summary Stats -*-*-*-*-*
# Earliest entry = 2019-01-02 10:12:53
# Most Recent entry = 2021-11-29 06:00:00
# Number of entries = 168075
# Number of Shop Orders = 4127

# %%
# %%time
df_clean = pd.DataFrame()
for so, frame in df.groupby(by = 'shop_order'):
    if re.match('[0-9]*6',so) is None: continue
    elif len(so) != 6: continue
    df_clean.loc[so,'tool']      = frame['tool'].iloc[0]
    df_clean.loc[so,'mach_name'] = frame['mach_name'].iloc[0]
    df_clean.loc[so,'resin']     = frame['resin'].iloc[0]
    df_clean.loc[so,'total_pieces'] = sum(frame['gross_pieces'])
    df_clean.loc[so,'start_time']= frame['start_time'].min()
    df_clean.loc[so,'end_time']  = frame['start_time'].max()
    df_clean.loc[so,'number of entries'] = len(frame)
df_clean = df_clean.reset_index()\
                    .rename(columns = {'index':'shop_order'})\
                    .sort_values(by = 'start_time')\
                    .reset_index(drop = True)
print('Number of Shop Orders = {}'.format(len(df_clean.shop_order.unique())))
df_clean.head()
# Out:
# Number of Shop Orders = 1402
# Wall time: 6.03 s
#   shop_order              tool mach_name  resin  total_pieces  \
# 0     185642            R7024L   65-T310  RM171       78654.0
# 1     185463            R7450A   91-T180  RM171     4217217.0
# 2     185610  R7028M-Thin-Wall   60-N500  RM129       16270.0
# 3     184693            R7605D   83-T390  RM171      147572.0
# 4     184856            R7028J   80-H440  RM171       28138.0
#
#            start_time            end_time  number of entries
# 0 2019-01-02 10:12:53 2019-01-21 14:00:00               59.0
# 1 2019-01-02 10:26:01 2019-01-13 18:00:01               20.0
# 2 2019-01-02 14:00:00 2019-02-14 22:00:00               71.0
# 3 2019-01-02 14:00:00 2019-01-23 06:00:00              126.0
# 4 2019-01-02 14:00:00 2019-01-10 14:00:00               25.0

# %%
df_clean.to_csv('./clean_data/plant_star.csv')

# %%
pd.crosstab(df_clean.tool,df_clean.resin)
# Out:
# resin            093  CM350LN  LH  N/A  PF535  PF535-0301001  PHILLIPS 66  \
# tool
# AM-171             0        0   0    1      0              0            0
# AM-208 FIP L- 2    0        0   0    2      0              0            0
# FIPC2              0        0   0    1      0              0            0
# IRS-001            0        0   0    1      0              0            0
# R 7417B            0        0   0    0      0              0            0
# ...              ...      ...  ..  ...    ...            ...          ...
# R7635A             0        0   0    0      0              0            0
# R7636A             0        0   0    0      0              0            0
# R7637A             0        0   0    0      0              0            0
# R8509B             0        0   0    0      0              0            0
# R8526B             0        0   0    0      0              0            0
#
# resin            PLYPRO /535  PRO FAX BASELL  PT00103021  ...  RM110  RM129  \
# tool                                                      ...
# AM-171                     0               0           0  ...      0      0
# AM-208 FIP L- 2            0               0           0  ...      0      0
# FIPC2                      0               0           0  ...      0      0
# IRS-001                    0               0           0  ...      0      0
# R 7417B                    0               0           0  ...      0      0
# ...                      ...             ...         ...  ...    ...    ...
# R7635A                     0               0           0  ...      0      2
# R7636A                     0               0           0  ...      0      0
# R7637A                     0               0           0  ...      0      2
# R8509B                     0               0           0  ...      0      2
# R8526B                     0               0           0  ...      0      3
#
# resin            RM157  RM160  RM165  RM168  RM169  RM171  RM176  rm129
# tool
# AM-171               0      0      0      0      0      0      0      0
# AM-208 FIP L- 2      0      0      0      0      0      0      0      0
# FIPC2                0      0      0      0      0      0      0      0
# IRS-001              0      0      0      0      0      0      0      0
# R 7417B              0      0      0      0      0      0      0      0
# ...                ...    ...    ...    ...    ...    ...    ...    ...
# R7635A               0      0      0      0      0      0      0      0
# R7636A               0      0      0      0      0      2      0      0
# R7637A               0      0      0      0      0      0      0      0
# R8509B               0      0      0      0      0      0      0      0
# R8526B               0      0      0      0      0      0      0      0
#
# [114 rows x 29 columns]

# %%
# %%time
plt.figure(figsize = (20,20))
sns.heatmap(pd.crosstab(df_clean.resin,df_clean.tool,normalize = True),linewidths=.1)
plt.show()
# Out:
# Wall time: 3.21 s
